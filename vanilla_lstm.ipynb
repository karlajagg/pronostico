# %% [markdown]
# # Pronóstico univariado a un paso usando LSTM

# %% [markdown]
# En este ejercicio aprenderemos a utilizar python para crear un modelo de pronóstico para una serie de datos de demanda eléctrica mensual. La entrada será una serie de tres pasos. El pronóstico tendrá un paso en adelanto. El paso de tiempo (timestep) tanto en la entrada como en la salida será de un mes. Como técnica de aprendizaje utilizaremos una red LSTM vanilla.

# %% [markdown]
# ## Preparación de los datos

# %% [markdown]
# Antes de utilizar una serie univariada para construir un modelo de pronóstico, ésta primero se debe preparar. El algoritmo LSTM aprenderá una función que asocia una secuencia de observaciones pasadas (entrada) con una observación de salida (pronóstico). Como tal, la secuencia de observaciones debe transformarse en múltiples ejemplos de los que la red LSTM pueda aprender.
#
# Por ejemplo, considere una secuencia univariada simple como ésta:

# %% [markdown]
# \\begin{matrix}10 & 20 & 30 & 40 & 50 & 60 & 70 & 80 & 90 \\\end{matrix}

# %% [markdown]
# Podemos dividir la secuencia en múltiples patrones de entrada / salida (muestras), donde se usan tres pasos de tiempo como entrada y un paso de tiempo como salida para la predicción a un solo paso en el futuro.

# %% [markdown]
# \\begin{matrix}x &  &  & & y \\10 & 20 & 30 & & 40 \\20 & 30 & 40 & & 50\\30 & 40 & 50 & & 60 \\\end{matrix}

# %% [markdown]
# Gráficamente, se puede ver como una ventana $W$ con una secuencia de valores donde el último valor $P_1$ es un siguiente paso en el tiempo. Usándo otro ejemplo, con cuatro valores, se puede ver así:

# %% [markdown]
# ![ventanasTiempo.png](data:image/png;base64,...)

# %% [markdown]
# La función split_sequence() implementa este comportamiento dividiendo una secuencia univariada  en múltiples muestras, donde cada muestra tiene un número específico de pasos de tiempo (timestep) y la salida  un solo paso de tiempo.

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense

# %%
# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %% [markdown]
# Usemos la función para el ejemplo gráfico. Queda de ejercicio, hacerlo para la secuencia de enteros de la primera parte.

# %%
# definimos una secuencia de entrada 
secuencia_cruda = [0.3509, 0.2452, 0.1094, 0.3169, 0.4566, 0.1773, 0.1056, 0.1132]
# escogemos el número de pasos 
n_pasos = 4
# separamos en muestras del tipo X, y (donde X es un vector y y un escalar)
X, y = split_sequence(secuencia_cruda, n_pasos)
# repasamos los ejemplos para ver como quedaron
for i in range(len(X)):
	print(X[i], y[i])
# Out:
# [0.3509 0.2452 0.1094 0.3169] 0.4566
# [0.2452 0.1094 0.3169 0.4566] 0.1773
# [0.1094 0.3169 0.4566 0.1773] 0.1056
# [0.3169 0.4566 0.1773 0.1056] 0.1132

# %% [markdown]
# Ahora sí, usémos datos reales de demanda máxima. Para esto recurriremos a una base de datos en Kaggle con datos históricos públicos de [demanda eléctrica en Australia](https://www.kaggle.com/dcervan/demanda-electrica-australia). Se trata de información mensual desde 1980 a 1995 (15 años).
# Carguemos los datos desde drive e imprimamos los datos para conocerlos.

# %%
# montamos la unidad de drive en colab
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import csv
import numpy as np

# %%
data_path= 'gdrive/My Drive/INEEL/cemie redes/PE-A-09/datasets/Demanda_electricidad_mensual-2-sinFecha.csv'
#data_path= 'gdrive/My Drive/INEEL/cemie redes/PE-A-09/datasets/Demanda_electricidad_anual-sinFecha.csv'

with open(data_path, 'r') as f:
    reader = csv.reader(f, delimiter=',')
    headers = next(reader)
    raw_seq = np.array(list(reader)).astype(float)
    raw_seq = [row[0] for row in raw_seq]

print(raw_seq)
# Out:
# [7366.0, 7414.0, 7824.0, 7524.0, 8279.0, 8707.0, 9486.0, 8973.0, 8231.0, 8206.0, 7927.0, 7999.0, 7834.0, 7521.0, 8284.0, 7999.0, 8940.0, 9381.0, 10078.0, 9796.0, 8471.0, 8572.0, 8150.0, 8168.0, 8166.0, 7903.0, 8606.0, 8071.0, 9178.0, 9873.0, 10476.0, 9296.0, 8818.0, 8697.0, 8381.0, 8293.0, 7942.0, 8001.0, 8744.0, 8397.0, 9115.0, 9773.0, 10358.0, 9849.0, 9083.0, 9143.0, 8800.0, 8741.0, 8492.0, 8795.0, 9354.0, 8796.0, 10072.0, 10174.0, 11326.0, 10744.0, 9806.0, 9740.0, 9373.0, 9244.0, 9407.0, 8827.0, 9880.0, 9364.0, 10580.0, 10899.0, 11687.0, 11280.0, 10208.0, 10212.0, 9725.0, 9721.0, 9846.0, 9407.0, 10265.0, 9970.0, 10801.0, 11246.0, 12167.0, 11578.0, 10645.0, 10613.0, 10104.0, 10348.0, 10263.0, 9973.0, 10803.0, 10409.0, 11458.0, 11845.0, 12559.0, 12070.0, 11221.0, 11338.0, 10761.0, 11012.0, 10923.0, 10790.0, 11427.0, 10788.0, 11772.0, 12104.0, 12634.0, 12772.0, 11764.0, 11956.0, 11646.0, 11750.0, 11485.0, 11198.0, 12265.0, 11704.0, 12419.0, 13259.0, 13945.0, 13839.0, 12387.0, 12546.0
# ...

# %% [markdown]
# Grafiquemos la serie de tiempo tal cual se encuentra en el archivo para conocer su comportamiento

# %%
import matplotlib.pyplot as plt

plt.title('Demanda eléctrica ')
plt.plot(raw_seq)
plt.xlabel('mes de registro')
plt.ylabel('Demanda (GW-h)')
# Out:
# Text(0, 0.5, 'Demanda (GW-h)')

# %% [markdown]
# Generamos los datos de entrenamiento para los datos de demanda,

# %%
# escogemos el número de pasos de tiempo de la secuancia de entrada
n_steps = 3
# separamos en muestras
X, y = split_sequence(raw_seq, n_steps)
# reshape from [samples, timesteps] into [samples, timesteps, features]

# %% [markdown]
# Especificamos el número de atributos o característica (1 en este caso) y ponemos los datos en formato lista de matrices.

# %%
n_features = 1
#print('Antes:',X)
X = X.reshape((X.shape[0], X.shape[1], n_features))
#print('Después:',X)

# %% [markdown]
# Separamos los datos en datos de prueba (20%) y entrenamiento (80%).

# %%
from sklearn.model_selection import train_test_split
num_test = 0.20 # aquí se está especificando 20% para test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=num_test)

# %% [markdown]
# Aquí construimos un modelo LSTM Vanilla para pronóstico de series de tiempo, la cual tiene una sola capa oculta y una capa de salida.
#
# Iniciamos con un modelo secuencial al que le agregamos una celda LSTM de 50 unidades, especificamos su función de activación (RELU) y la forma de la entrada, en esta caso [***n_pasos,n_caracteristicas***]. Como salida usamos una capa densa con una salida única (valor de pronóstico). Como optimizador usamos Adam, y como métrica para convergencia el error mse. El entrenamiento se limita a 200 épocas.

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
#model.fit(X, y, epochs=200, verbose=0)
model.fit(X_train, y_train, epochs=200, verbose=0)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# Mostramos un resumen de las características de la red recurrente y una representación gráfica para tener mejor idea de la topología.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 50)                10400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...
# Total params: 10,451
# Trainable params: 10,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='gdrive/My Drive/INEEL/Cubico/grupo_pronostico/datos/model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# Guardamos todos los valores predichos para el conjunto de prueba (solo predicciones) en una lista llamada *lista* que después compararemos con los valores reales, guardados en *y_test*.

# %%
#l=X.reshape((X.shape[0],X.shape[1]))
l=X_test.reshape((X_test.shape[0],X_test.shape[1]))
lista=array([])
for i in l:
    i = i.reshape((1, n_steps, n_features))
    yhat = model.predict(i, verbose=0)
    lista=np.append(lista,yhat)
#print('end')

# %% [markdown]
# Mandamos a graficar los valores predichos (*lista*) en azul y los valores reales (*y_test*) en naranja.

# %%
import matplotlib.pyplot as plt

# graficamos el vector de salidas reales vs pronosticados
plt.title('Demanda eléctrica ')
plt.plot(lista)
#plt.plot(y)
# graficamos el valor real
plt.plot(y_test)
plt.xlabel('muestra')
plt.ylabel('Demanda (GW-h)')
# Out:
# Text(0, 0.5, 'Demanda (GW-h)')

# %% [markdown]
# Ahora crearemos una vista de los valores mostrando los datos pronosticados y los reales contra la secuencia que dió lugar a este valor. Usaremos esta función sencilla que aplicaremos más abajo.

# %%
def create_time_steps(length):
    return list(range(-length, 0))

def show_plot(plot_data, title):
    labels = ['Historia', 'Verdadero Futuro', 'Predicción']
    marker = ['.-', 'rx', 'go']
    time_steps = create_time_steps(plot_data[0].shape[0])
    future = 0

    plt.title(title)
    for i, x in enumerate(plot_data):
        if i:
            plt.plot(future, plot_data[i], marker[i], markersize=10,
                     label=labels[i])
        else:
            plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Pasos en tiempo')
    return plt

# %% [markdown]
# Aplicamos la función de graficación para que del conjunto de datos predichos obtenga la secuencia que predice y el valor real de demanda. Ejecutando repetidamente la celda de código podemos ver distintos pronósticos.

# %%
# i_sample=5
i_sample = np.random.randint(len(y_test))   # Tomar un ejemplo aleatorio
x_sample = l[i_sample]
x_sample = x_sample.reshape((1, n_steps, n_features))
y_sample = y_test[i_sample]
yhat = model.predict(x_sample, verbose=0)

plot = show_plot([l[i_sample], y_sample, yhat],'Pronóstico a un solo paso')

# %% [markdown]
# Calculamos el error medio absoluto porcentual (MAPE) para evaluar el modelo, el cual no es nada malo.

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

#mape=mean_absolute_percentage_error(lista, y)
mape=mean_absolute_percentage_error(lista, y_test)
print(mape)
# Out:
# 6.6293648555798885
